# %%
# !pip install torchsde
# Out:
# Collecting torchsde
#   Downloading torchsde-0.2.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.5 in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torchsde) (1.9.1)
# Collecting torch>=1.6.0
#   Downloading torch-2.2.2-cp39-none-macosx_10_9_x86_64.whl (150.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 13.5 MB/s eta 0:00:0000:0100:01
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: numpy>=1.19 in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torchsde) (1.24.4)
# Requirement already satisfied: networkx in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (2.8.4)
# Requirement already satisfied: sympy in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (1.10.1)
# Requirement already satisfied: fsspec in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (2022.7.1)
# Collecting typing-extensions>=4.8.0
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: jinja2 in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (2.11.3)
# Requirement already satisfied: filelock in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from torch>=1.6.0->torchsde) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from jinja2->torch>=1.6.0->torchsde) (2.0.1)
# Requirement already satisfied: mpmath>=0.19 in /Users/vitorihaldijiran/opt/anaconda3/lib/python3.9/site-packages (from sympy->torch>=1.6.0->torchsde) (1.2.1)
# Installing collected packages: trampoline, typing-extensions, torch, torchsde
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
# Successfully installed torch-2.2.2 torchsde-0.2.6 trampoline-0.1.2 typing-extensions-4.12.2

# %%
import torch
import torchsde
import matplotlib.pyplot as plt

# Set random seed for reproducibility
torch.manual_seed(42)

# Parameters for the SDE
mu = 0.1  # Drift coefficient
sigma = 0.2  # Diffusion coefficient
x0 = 1.0  # Initial value
t0, t1 = 0.0, 1.0  # Start and end times
dt = 0.01  # Time step
num_samples = 5  # Number of sample paths

# Define the SDE
class GeometricBrownianMotion(torchsde.SDEIto):
    def __init__(self, mu, sigma):
        super().__init__(noise_type='diagonal')
        self.mu = mu
        self.sigma = sigma

    def f(self, t, y):
        return self.mu * y

    def g(self, t, y):
        return self.sigma * y

# Initialize the SDE
sde = GeometricBrownianMotion(mu=mu, sigma=sigma)

# Time points
ts = torch.linspace(t0, t1, int((t1 - t0) / dt) + 1)

# Initial value, reshaped to be 2-dimensional with multiple samples
y0 = torch.tensor([[x0]] * num_samples)

# Solve the SDE
ys = torchsde.sdeint(sde, y0, ts)

# Plot the results
for i in range(num_samples):
    plt.plot(ts.numpy(), ys[:, i, 0].numpy(), label=f'Sample {i+1}')
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Geometric Brownian Motion')
plt.legend()
plt.show()
